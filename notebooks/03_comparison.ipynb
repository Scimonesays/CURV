# %% [markdown]
# # 03 Comparison
#
# Run GR + graph + comparison.

# %%
from src.gr_schwarzschild import run_gr_sweep
from src.emergent_graph import run_graph_model
from src.compare import run_comparison

run_gr_sweep()
run_graph_model()
run_comparison()
